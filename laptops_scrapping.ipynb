# %% [markdown]
# # Web scrapping in Mercado Libre
# ---
# ---
# This web scrapping exercise is intented to show the process to extract data from the website 'Mercado Libre' a various product selling platform in Latin America. The URL for extraction is taken from the website for Mexico, and the product chosen is 'Laptops'.
# ## Importing libraries
# The libraries we wil be using for this exercise are: 'requests' for sending the HTTP requests, 'BeautifulSoup' for parsing the unwanted data and helping to organize and format the messy web data by fixing bad HTML and be presented to us in easily-traversible XML structures, 'pandas' for analysing our scrapped data, and 'namedtuple' for creating simple, lightweight data structures similar to a class, but without the overhead of defining a full class.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import namedtuple

# %% [markdown]
# Afterwards, we declare the URL we will be applying the web srapping to, that for this case will be for laptops.
# We define our 'namedtuple' to store the information we extract from the URL as name, previous price, current price, discount and the image url per product as a list.
# We finally declare the product list that will start empty to store all the products of type namedtuple extracted from our scrapping.

# %%
url = "https://listado.mercadolibre.com.mx/laptops#D[A:laptops]"
Product = namedtuple('Product', ['name','prev_price','curr_price','discount','url_image'])
product_list = []

# %% [markdown]
# We proceed to connect with the site using 'requests' to extract the info of the URL. Then, we need the text and we call the contents with the attribute 'text'.

# %%
r = requests.get(url)
html_contents=r.text

# %% [markdown]
# Then we create our 'BeautifulSoup' object with the html requested from MercadoLibre 'html_contents' and the html parser to standardize and to avoid conflicts with versions. Finally, with this we will have stablished a successful connection with the site.

# %%
html_soup = BeautifulSoup(html_contents,'html.parser')

# %% [markdown]
# # Starting the analysis
# We need to define the products we will be analysing from the site, so, we go through the website to see how the information we require is stored and organised by revising their html structure. By this we can identify that each of the products(laptops) information is stored in the class "ui-search-layout__item".
# Then, we create our variable 'products_mercado' containing our target product and by using our BeautifulSoup object and using '.find_all'with the tag and class name, we extract all the listed laptops included in the website. We are ready to create a 'for' cycle to extract the information we need for all the products.

# %%
products_mercado = html_soup.find_all('li',class_="ui-search-layout__item")

# %% [markdown]
# # The 'for' cycle
# ---
# ## Creating the cycle
# After determining the list of items to use, by finding the respective class, it is required to create a 'for' cycle where we can get the details
# of our data. Remember that for each product we need the name, the previous price (if any), the current price, the discount (if any as well), and the image url.
# The argument 'try' is used for those products that have a previous price and/or discount, and the argument 'except' is used for those products that do not have a previous price and/or discount.
# ## Replacing data types
# As most data is a type 'string' we should make sure 'int' types are designated as correspond: for the previous price and current price, we replace the commas for blanks and for discount we replace '% OFF' also with a blank, and in 'append' we cast the elements that should be 'int' types, as for this case, to previous price(prev_price), current price(curr_price) and discount.

# %%
for product in products_mercado:
    name = product.find('h2',class_="ui-search-item__title shops__item-title").text
    try:
        prev_price = product.find('s',class_='andes-money-amount').find('span',class_='andes-money-amount__fraction').text
        discount = product.find('span',class_="ui-search-price__second-line__label shops__price-second-line__label").find('span',class_="ui-search-price__discount shops__price-discount").text
    except AttributeError:
        prev_price = '0'
        discount = '0'
    curr_price = product.find('span',class_='andes-money-amount').find('span',class_='andes-money-amount__fraction').text
    prev_price = prev_price.replace(',','')
    curr_price = curr_price.replace(',','')
    discount = discount.replace('% OFF','')
    image = product.find('img')
    product_list.append(Product(name,int(prev_price),int(curr_price),int(discount),image.attrs['data-src']))

# %% [markdown]
# # Organising the data into a DataFrame and analysis execution
# ---
# Now, to make our data easy-to-read, we create a Pandas DataFrame in order to match the 'product_list' columns with our fields in our designated namedtuple 'Product', and we wil be able to have our data better organised.

# %%
df = pd.DataFrame(product_list,columns=Product._fields)

# %% [markdown]
# Afterwards, we just revise our organisation by extracting a sample, which for this case will be of 5 items.

# %%
df.sample(5)
# Out:
#                                                  name  prev_price  curr_price  \
# 15  Laptop Gamer Msi Gf63 Thin Geforce Gtx 1650 Co...       18499       14899
# 37  Laptop  Acer C733 shale black 11.6", Intel Cel...           0        4299
# 51  Laptop Huawei Matebook D15 Core I5 11.5th 8gb ...       16999       12499
# 68  Laptop Gamer Dell Ryzen 5 3450u 12gb 1tb 256gb...       14899       12499
# 80  Laptop  gamer  Thunderobot Zero Ultra plata y ...       49119       30945
#
#     discount                                          url_image
# 15        19  https://http2.mlstatic.com/D_NQ_NP_747423-MLA5...
# 37         0  https://http2.mlstatic.com/D_NQ_NP_864557-MLA4...
# 51        26  https://http2.mlstatic.com/D_NQ_NP_948505-MLU7...
# 68        16  https://http2.mlstatic.com/D_NQ_NP_770187-MLU7...
# 80        37  https://http2.mlstatic.com/D_NQ_NP_937867-MLA7...

# %% [markdown]
# We can see now that our scrapped data from the web is matching our namedtuple.

# %% [markdown]
# # Analysing current price
# Now that our data is cleaned and organised, we can proceed to find the Laptops ranging from $8,000 MXN and under that price; therefore, we filter our DataFrame as shown below.

# %%
df[df['curr_price']<=8000]
# Out:
#                                                  name  prev_price  curr_price  \
# 2   Laptop Hp 245 G8 14  Pulgadas Procesador Amd R...       10999        6598
# 3   Hp 14-dq0052dx 14 Celeron 4gb Ram 64gb Ssd Sno...        7299        4159
# 5   Laptop  Gateway Ultra Slim GWNR51416 green 14....           0        7005
# 6   Laptop Lenovo Ideapad 15.6 Ryzen 3 7320u 8gb 2...       15999        7299
# 10  Inter Laptop Aocwei 15.6  6gb+scalable Ssd Win...        9637        4818
# 11  Laptop 14, Intel Celeron J4105 8gb Ram 120gb S...        5247        3725
# 12  Hp (15-dy3008ca) 15.6  Celeron N4500 8gb 256gb...        5470        4649
# 16  Laptop Chuwi HeroBook Pro space gray 14.1", In...        5773        5080
# 17  Laptop Aocwei 15.6 6+256gb Scalable Ssd Window...        9637        4818
# 20  Laptop Chromebook Touch - 16gb 4gb Ram Wfi Web...           0        1399
# 21  Hp Probook 440 G2 I5 4210u 8 Y 500 Hdd Camara ...           0        2900
# 22  Laptop Dell Inspiron 3511, 8gb+mochila Pro_mel...        7999        6799
# 23  Lenovo Thinkpad X280 Core I5-8350u 16gbram 1tb...        6590        6128
# 24           Dell    I7-4t 240 Gb Ssd Y 8gb Ram E7440        4500        4275
# 26  Laptop Dell Latitude Core I7 7th Gen 16gb Ram ...           0        7990
# 27  Laptop 14, Intel Celeron J4105 6gb Ram 120gb S...        4896        3623
# 28  Laptop Dell Barata I5 8va Gen 16gb Ram 512gb S...        8499        5694
# 29  Acer Chromebook Spin 11 Intel N3350 4gb Laptop...        2388        1528
# 32  Laptop Asus 15.6'' Ram 8gb / 256gb + 1tb X515e...       13999        7299
# 33  Laptop Hp Elitebook 840 G5 Core I5-8350 16gb 5...           0        6099
# 35  Laptop 14.1'' Notebook 8gb+256gb Ssd Intel N40...       15794        4738
# 37  Laptop  Acer C733 shale black 11.6", Intel Cel...           0        4299
# 41  Laptop Hybook, 14.1  Celeron N3060, 4gb 64gb +...           0        4244
# 42  Laptop  HP 240 G9 plateada 14", Intel Celeron ...        6999        5299
# 43  Laptop Hp 245 G9 Amd Ryzen 3 3250u 8gb Ssd 512...       11999        7399
# 45  Laptop Hp 14-dq0526la Intel Celeron 4gb Ram 12...        7999        4959
# 47  Hp Probook 445 G8 Ryzen5 5600u Amd 16gb Ram 51...           0        6999
# 52  Laptop Hp 245 G8 14  Pulgadas Procesador Amd R...       10999        6598
# 53  Hp 14-dq0052dx 14 Celeron 4gb Ram 64gb Ssd Sno...        7299        4159
# 55  Laptop  Gateway Ultra Slim GWNR51416 green 14....           0        7005
# 56  Laptop Lenovo Ideapad 15.6 Ryzen 3 7320u 8gb 2...       15999        7299
# 60  Inter Laptop Aocwei 15.6  6gb+scalable Ssd Win...        9637        4818
# 61  Laptop 14, Intel Celeron J4105 8gb Ram 120gb S...        5247        3725
# 62  Hp (15-dy3008ca) 15.6  Celeron N4500 8gb 256gb...        5470        4649
# 66  Laptop Chuwi HeroBook Pro space gray 14.1", In...        5773        5080
# 67  Laptop Aocwei 15.6 6+256gb Scalable Ssd Window...        9637        4818
# 70  Laptop Chromebook Touch - 16gb 4gb Ram Wfi Web...           0        1399
# 71  Hp Probook 440 G2 I5 4210u 8 Y 500 Hdd Camara ...           0        2900
# 72  Laptop Dell Inspiron 3511, 8gb+mochila Pro_mel...        7999        6799
# 73  Lenovo Thinkpad X280 Core I5-8350u 16gbram 1tb...        6590        6128
# 74           Dell    I7-4t 240 Gb Ssd Y 8gb Ram E7440        4500        4275
# 76  Laptop Dell Latitude Core I7 7th Gen 16gb Ram ...           0        7990
# 77  Laptop 14, Intel Celeron J4105 6gb Ram 120gb S...        4896        3623
# 78  Laptop Dell Barata I5 8va Gen 16gb Ram 512gb S...        8499        5694
# 79  Acer Chromebook Spin 11 Intel N3350 4gb Laptop...        2388        1528
# 82  Laptop Asus 15.6'' Ram 8gb / 256gb + 1tb X515e...       13999        7299
# 83  Laptop Hp Elitebook 840 G5 Core I5-8350 16gb 5...           0        6099
# 85  Laptop 14.1'' Notebook 8gb+256gb Ssd Intel N40...       15794        4738
# 87  Laptop  Acer C733 shale black 11.6", Intel Cel...           0        4299
# 91  Laptop Hybook, 14.1  Celeron N3060, 4gb 64gb +...           0        4244
# 92  Laptop  HP 240 G9 plateada 14", Intel Celeron ...        6999        5299
# 93  Laptop Hp 245 G9 Amd Ryzen 3 3250u 8gb Ssd 512...       11999        7399
# 95  Laptop Hp 14-dq0526la Intel Celeron 4gb Ram 12...        7999        4959
# 97  Hp Probook 445 G8 Ryzen5 5600u Amd 16gb Ram 51...           0        6999
#
#     discount                                          url_image
# 2         40  https://http2.mlstatic.com/D_NQ_NP_836775-MLA5...
# 3         43  https://http2.mlstatic.com/D_NQ_NP_882543-MLA5...
# 5          0  https://http2.mlstatic.com/D_NQ_NP_902361-MLA5...
# 6         54  https://http2.mlstatic.com/D_NQ_NP_685676-MLA5...
# 10        50  https://http2.mlstatic.com/D_NQ_NP_820770-MLM7...
# 11        28  https://http2.mlstatic.com/D_NQ_NP_832127-CBT7...
# 12        15  https://http2.mlstatic.com/D_NQ_NP_892296-MLU7...
# 16        11  https://http2.mlstatic.com/D_NQ_NP_723065-MLA4...
# 17        50  https://http2.mlstatic.com/D_NQ_NP_653948-MLM7...
# 20         0  https://http2.mlstatic.com/D_NQ_NP_883687-MLM5...
# 21         0  https://http2.mlstatic.com/D_NQ_NP_878496-MLM7...
# 22        15  https://http2.mlstatic.com/D_NQ_NP_976198-MLM7...
# 23         7  https://http2.mlstatic.com/D_NQ_NP_918372-MLM7...
# 24         5  https://http2.mlstatic.com/D_NQ_NP_831568-MLM5...
# 26         0  https://http2.mlstatic.com/D_NQ_NP_981696-MLM7...
# 27        25  https://http2.mlstatic.com/D_NQ_NP_982814-CBT5...
# 28        33  https://http2.mlstatic.com/D_NQ_NP_770807-MLM6...
# 29        36  https://http2.mlstatic.com/D_NQ_NP_822151-MLM6...
# 32        47  https://http2.mlstatic.com/D_NQ_NP_713596-MLM6...
# 33         0  https://http2.mlstatic.com/D_NQ_NP_915965-MLM7...
# 35        70  https://http2.mlstatic.com/D_NQ_NP_624565-CBT7...
# 37         0  https://http2.mlstatic.com/D_NQ_NP_864557-MLA4...
# 41         0  https://http2.mlstatic.com/D_NQ_NP_829634-MLU7...
# 42        24  https://http2.mlstatic.com/D_NQ_NP_809147-MLA5...
# 43        38  https://http2.mlstatic.com/D_NQ_NP_918846-MLU5...
# 45        38  https://http2.mlstatic.com/D_NQ_NP_632744-MLU6...
# 47         0  https://http2.mlstatic.com/D_NQ_NP_874786-MLM7...
# 52        40  https://http2.mlstatic.com/D_NQ_NP_836775-MLA5...
# 53        43  https://http2.mlstatic.com/D_NQ_NP_882543-MLA5...
# 55         0  https://http2.mlstatic.com/D_NQ_NP_902361-MLA5...
# 56        54  https://http2.mlstatic.com/D_NQ_NP_685676-MLA5...
# 60        50  https://http2.mlstatic.com/D_NQ_NP_820770-MLM7...
# 61        28  https://http2.mlstatic.com/D_NQ_NP_832127-CBT7...
# 62        15  https://http2.mlstatic.com/D_NQ_NP_892296-MLU7...
# 66        11  https://http2.mlstatic.com/D_NQ_NP_723065-MLA4...
# 67        50  https://http2.mlstatic.com/D_NQ_NP_653948-MLM7...
# 70         0  https://http2.mlstatic.com/D_NQ_NP_883687-MLM5...
# 71         0  https://http2.mlstatic.com/D_NQ_NP_878496-MLM7...
# 72        15  https://http2.mlstatic.com/D_NQ_NP_976198-MLM7...
# 73         7  https://http2.mlstatic.com/D_NQ_NP_918372-MLM7...
# 74         5  https://http2.mlstatic.com/D_NQ_NP_831568-MLM5...
# 76         0  https://http2.mlstatic.com/D_NQ_NP_981696-MLM7...
# 77        25  https://http2.mlstatic.com/D_NQ_NP_982814-CBT5...
# 78        33  https://http2.mlstatic.com/D_NQ_NP_770807-MLM6...
# 79        36  https://http2.mlstatic.com/D_NQ_NP_822151-MLM6...
# 82        47  https://http2.mlstatic.com/D_NQ_NP_713596-MLM6...
# 83         0  https://http2.mlstatic.com/D_NQ_NP_915965-MLM7...
# 85        70  https://http2.mlstatic.com/D_NQ_NP_624565-CBT7...
# 87         0  https://http2.mlstatic.com/D_NQ_NP_864557-MLA4...
# 91         0  https://http2.mlstatic.com/D_NQ_NP_829634-MLU7...
# 92        24  https://http2.mlstatic.com/D_NQ_NP_809147-MLA5...
# 93        38  https://http2.mlstatic.com/D_NQ_NP_918846-MLU5...
# 95        38  https://http2.mlstatic.com/D_NQ_NP_632744-MLU6...
# 97         0  https://http2.mlstatic.com/D_NQ_NP_874786-MLM7...

# %% [markdown]
# # Conclusions
# ---
# From here we can start making decisions as we could obtain the products that comply with the condition we stablished. The best part is that every time the code is run, the data will be up to date to be choosing from the best current options.
